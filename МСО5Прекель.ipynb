# %% [markdown]
# # Домашняя работа 5 МСО Прекель В.А.

# %% [markdown]
# ### № 2.7.3
#
# > Вычислите  математическое  ожидание  и  дисперсию  дискретной  слу-чайной величины, возможные значения которой равновероятны.
#
# $p_1 = p_2 = ... = p_n = p$

# %% [markdown]
# $M(X) = \sum_{i=1}^{n} p_ix_i = p\sum_{i=1}^{n} x_i = \frac{\sum_{i=1}^{n} x_i}{n} = X$ (Среднее арифметическое всех значений функций)

# %% [markdown]
# $D(X) = \sum_{i=1}^{n} (x_i - M(X))^2p_i = \frac{\sum_{i=1}^{n} (x_i - \frac{\sum_{i=1}^{n} x_i}{n})}{n}$

# %% [markdown]
# ### № 2.7.5
#
# > Вычислите все начальные моменты для следующих  усеченных сим-метричных (относительно нулевого значения) законов распределения:

# %% [markdown]
# А) $M(X) = \int_{-1}^{1} x^r * \frac{1}{2}dx = \frac{1}{2} \int_{-1}^{1} x^r dx$
#
# Б) $M(X) = \int_{-1}^{1} x^r * (1 - |x|)dx = \int_{-1}^{1} (x^r - |x| x^r) dx$
#
# В) $M(X) = \int_{-1}^{1} x^r * (\frac{3}{4} - \frac{3}{4}x^2)dx = \frac{3}{4} \int_{-1}^{1} (x^r - x^{r + 2})dx$
#
# Г) $M(X) = \int_{-1}^{1} x^r * (1 + 2|x|) * (1 - |x|)^2dx$

# %% [markdown]
# ### № 2.9.1
#
# > На  основе  использования  характеристической  функции  (2.9.10)  для равномерно распределенной случайной величины рассчитайте:а) первый начальный момент,б) второй начальный момент,в) первый центральный момент,г) второй центральный момент.

# %% [markdown]
# а) $\alpha_1 = \int_{\alpha}^{\beta} \frac{x}{i\lambda(\beta-\alpha)} (e^{i\lambda\beta} - e^{i\lambda\alpha})dx$
#
# б) $\alpha_2 = \int_{\alpha}^{\beta} \frac{x^2}{i\lambda(\beta-\alpha)} (e^{i\lambda\beta} - e^{i\lambda\alpha})dx$
#
# в) $\mu_1 = \int_{\alpha}^{\beta} \frac{(x - \int_{\alpha}^{\beta} \frac{x}{i\lambda(\beta-\alpha)} (e^{i\lambda\beta} - e^{i\lambda\alpha})dx)}{i\lambda(\beta-\alpha)}(e^{i\lambda\beta} - e^{i\lambda\alpha})dx$
#
# г) $\mu_2 = \int_{\alpha}^{\beta} \frac{(x - \int_{\alpha}^{\beta} \frac{x}{i\lambda(\beta-\alpha)} (e^{i\lambda\beta} - e^{i\lambda\alpha})dx)^2}{i\lambda(\beta-\alpha)}(e^{i\lambda\beta} - e^{i\lambda\alpha})dx$

# %% [markdown]
# ### № 2.9.2
#
# > На  основе  использования  характеристической  функции  (2.9.11)  для экспоненциально  распределенной  случайной  величины  рассчитайте  моменты, указанные в упражнении 2.9.1.

# %% [markdown]
# А) $\alpha_1 = \int_0^{\infty} \frac{\alpha x}{\alpha - i\lambda}dx$
#
# Б) $\alpha_2 = \int_0^{\infty} \frac{\alpha x^2}{\alpha - i\lambda}dx$
#
# В) $\mu_1 = \int_0^{\infty} \frac{\alpha(x - \int_0^{\infty} \frac{\alpha x}{\alpha - i\lambda}dx)}{\alpha - i\lambda}dx$
#
# Г) $\mu_2 = \int_0^{\infty} \frac{\alpha(x - \int_0^{\infty} \frac{\alpha x}{\alpha - i\lambda}dx)^2}{\alpha - i\lambda}dx$

# %% [markdown]
# ### № 2.9.3
#
# > На  основе  использования  характеристической    функции  (2.9.2)  дис-кретной случайной величины с равновероятными возможными значениями вы-числите моменты, указанные в упражнении 2.9.1

# %% [markdown]
# а) $\alpha_1 = \sum_{k=1}^{n} e^{i\lambda x_k} * p_{x_k}$
#
# б) $\alpha_2 = \sum_{k=1}^{n} e^{2i\lambda x_k} * p_{x_k}$
#
# в) $\mu_1 = \sum_{k=1}^{n} (e^{i\lambda x_k}- \sum_{k=1}^{n} e^{i\lambda x_k} * p_{x_k}) * p_{x_k}$
#
# г) $\mu_2 = \sum_{k=1}^{n} (e^{2i\lambda x_k}- \sum_{k=1}^{n} e^{i\lambda x_k} * p_{x_k}) * p_{x_k}$
