# %%
import sympy as sp
x, a = sp.symbols('x a')

# %% [markdown]
# ### Найдем параметр

# %%
f_x = a * (1 - x ** 2)
f_x_integral = sp.integrate(f_x, (x, -1, 1))
f_x_integral
# Out:
# 4*a/3

# %% [markdown]
# ###

# %%
a = sp.solve(sp.Eq( 4 * a / 3 ,  1 ))
a
# Out:
# [3/4]

# %% [markdown]
# ### Параметр равен a = 3 / 4
# ### Теперь найдем мат. ожидание

# %%
f_x = (3 / 4) * (1 - x ** 2)
m_x = sp.integrate(x * f_x, (x, -1, 1))
m_x
# Out:
# 0

# %% [markdown]
# ### Мат. ожидание равно 0

# %% [markdown]
# ### Найдем дисперсию

# %%
d_x = sp.integrate(f_x * (x - m_x) ** 2, (x, -1, 1))
d_x
# Out:
# 0.200000000000000

# %% [markdown]
# ### Найдем среднеквадратическое отклонение

# %%
s = d_x ** (1/2)
s
# Out:
# 0.447213595499958

# %% [markdown]
# ### Функция распределения вероятности

# %%
F_x = sp.integrate(0, (x, -sp.oo, -1))
F_x
# Out:
# 0

# %%
F_x = sp.integrate(f_x, (x, -1, x))
F_x
# Out:
# -0.25*x**3 + 0.75*x + 0.5
