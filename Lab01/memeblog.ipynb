# %% [markdown]
# # Модели стохастических объектов (методы анализа данных)
# ## Практическая работа №1
# ### КИ18-16 Прекель В.А.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_json("memeblog.json")
data
# Out:
#          OwnerId      Id                      Date AttachmentTypes  Comments  \
# 0     -120075923       1 2016-04-23 18:49:13+00:00         [photo]        28
# 1     -120075923       2 2016-04-23 19:18:26+00:00         [photo]         1
# 2     -120075923       3 2016-04-23 19:35:32+00:00         [photo]         0
# 3     -120075923       4 2016-04-23 19:35:39+00:00         [photo]         8
# 4     -120075923       7 2016-04-23 20:24:46+00:00              []         9
# ...          ...     ...                       ...             ...       ...
# 38396 -120075923  770804 2021-02-06 07:40:20+00:00  [photo, photo]        42
# 38397 -120075923  770886 2021-02-06 09:52:19+00:00  [photo, audio]         0
# 38398 -120075923  770899 2021-02-06 10:30:03+00:00         [video]        26
# 38399 -120075923  770960 2021-02-06 15:13:11+00:00         [photo]        21
# 38400 -120075923  770997 2021-02-06 16:18:44+00:00         [video]         7
#
#        Likes  Reposts    Views     FromId PostSource PostType  SignerId  \
# 0         61        1      NaN -120075923        api     post       NaN
# 1        121        2      NaN -120075923        api     post       NaN
# 2        225        9      NaN -120075923        api     post       NaN
# 3         38        0      NaN -120075923        api     post       NaN
# 4         45        0      NaN -120075923         vk     post       NaN
# ...      ...      ...      ...        ...        ...      ...       ...
# 38396    286      148  15342.0 -120075923         vk     post       NaN
# 38397     43        1   8864.0 -120075923         vk     post       NaN
# 38398    359      115  14474.0 -120075923        api     post       NaN
# 38399    426      221  13860.0 -120075923        api     post       NaN
# 38400     86       54   6074.0 -120075923        api     post       NaN
#
#        MarkedAsAds
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 38396            0
# 38397            0
# 38398            0
# 38399            0
# 38400            0
#
# [38401 rows x 13 columns]

# %%
# data.groupby(['SignerId']).groups

# %%
np.mean(data.Comments)
# Out:
# 14.684018645347777

# %%
np.median(data.Comments)
# Out:
# 11.0

# %%
np.var(data.Comments)
# Out:
# 411.18814307550974

# %%
np.std(data.Comments)
# Out:
# 20.277774608558744

# %%
plt.figure(figsize=(15, 10))
sns.displot(data['Views'])

# %%
plt.figure(figsize=(20, 20))
data['AttachmentTypes'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='AttachmentTypes'>

# %%
t = data.Date.groupby(by=pd.to_datetime(data.Date).dt.date)

# %%
plt.figure(figsize=(15, 10))
data["DateWithoutTime"] = pd.to_datetime(data.Date).dt.strftime('%Y %h')
sns.boxplot(x="DateWithoutTime", y="Likes", data = data)
# Out:
# <AxesSubplot:xlabel='DateWithoutTime', ylabel='Likes'>

# %%
plt.figure(figsize=(15, 10))
data["DateWithoutTime"] = pd.to_datetime(data.Date).dt.strftime('%Y %h')
sns.boxplot(x="DateWithoutTime", y="Views", data = data)

# %%
plt.figure(figsize=(15, 10))
data["DateWithoutTime"] = pd.to_datetime(data.Date).dt.strftime('%Y %h')
sns.boxplot(x="DateWithoutTime", y="Comments", data = data)
# Out:
# <AxesSubplot:xlabel='DateWithoutTime', ylabel='Comments'>
