# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_json("7.json")
data
# Out:
#          OwnerId      Id                      Date AttachmentTypes  Comments  \
# 0     -120075923       1 2016-04-23 18:49:13+00:00         [photo]        28
# 1     -120075923       2 2016-04-23 19:18:26+00:00         [photo]         1
# 2     -120075923       3 2016-04-23 19:35:32+00:00         [photo]         0
# 3     -120075923       4 2016-04-23 19:35:39+00:00         [photo]         8
# 4     -120075923       7 2016-04-23 20:24:46+00:00              []         9
# ...          ...     ...                       ...             ...       ...
# 38396 -120075923  770804 2021-02-06 07:40:20+00:00  [photo, photo]        42
# 38397 -120075923  770886 2021-02-06 09:52:19+00:00  [photo, audio]         0
# 38398 -120075923  770899 2021-02-06 10:30:03+00:00         [video]        26
# 38399 -120075923  770960 2021-02-06 15:13:11+00:00         [photo]        21
# 38400 -120075923  770997 2021-02-06 16:18:44+00:00         [video]         7
#
# ...

# %%
data.groupby(['SignerId']).groups
# Out:
# {832960.0: [23209], 1257468.0: [20021], 2404548.0: [20345], 3071028.0: [7613, 8592, 9634], 3142905.0: [5696, 7557, 7795, 11740, 15431], 3717330.0: [20154, 29399], 3851628.0: [19936, 20750], 4648548.0: [28633], 5165708.0: [24766], 5168518.0: [8695, 11458, 23662], 5856772.0: [4898], 5883771.0: [8770], 5962419.0: [29080], 6585517.0: [5000, 5041, 5145], 6770849.0: [19892], 7192087.0: [11168], 7435104.0: [38142], 7625642.0: [28703, 34458, 38009], 7650728.0: [32018], 7850251.0: [8106, 27048], 7915080.0: [24242, 28461], 8482684.0: [6327, 16237], 8886452.0: [25849], 8943569.0: [32675], 9109152.0: [22665], 9249651.0: [33769, 33805], 9558440.0: [28338], 9574726.0: [24750, 24752], 9613755.0: [29699], 10112665.0: [28940, 30156, 30421, 30424, 30475], 10155138.0: [16525], 10388636.0: [37768], 10443821.0: [21545, 21554, 27668, 28960], 10744130.0: [28032], 10770953.0: [1124, 3602, 4499, 9859, 25045], 10852502.0: [2527], 10905717.0: [11374], 10944621.0: [13452, 14615, 14738, 15983, 21085], 11127007.0
# ...

# %%
np.mean(data.Comments)
# Out:
# 14.684018645347777
